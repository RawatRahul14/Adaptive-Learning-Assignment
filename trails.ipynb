# %%
from src.puzzle_generator import generate_question

# %%
age = [5, 6, 7, 8, 9, 10]
level = ["easy", "medium", "hard"]

# %%
for a in age:
    for l in level:
        question, answer = generate_question(
            age = a,
            level = l
        )

        print(f"Age: {a} and Level: {l}")
        print(f"\tQuestion: {question} and answer: {answer}")
# Out:
# Age: 5 and Level: easy
# 	Question: 7 + 4 = ? and answer: 11
# Age: 5 and Level: medium
# 	Question: 6 - 4 = ? and answer: 2
# Age: 5 and Level: hard
# 	Question: 12 - 7 = ? and answer: 5
# Age: 6 and Level: easy
# 	Question: 9 - 8 = ? and answer: 1
# Age: 6 and Level: medium
# 	Question: 12 - 12 = ? and answer: 0
# Age: 6 and Level: hard
# 	Question: 48 - 12 = ? and answer: 36
# Age: 7 and Level: easy
# 	Question: 5 - 5 = ? and answer: 0
# Age: 7 and Level: medium
# 	Question: 36 + 11 = ? and answer: 47
# Age: 7 and Level: hard
# 	Question: 27 * 5 = ? and answer: 135
# Age: 8 and Level: easy
# 	Question: 4 - 1 = ? and answer: 3
# Age: 8 and Level: medium
# 	Question: 27 - 19 = ? and answer: 8
# Age: 8 and Level: hard
# 	Question: 56 + 18 = ? and answer: 74
# Age: 9 and Level: easy
# 	Question: 10 - 7 = ? and answer: 3
# Age: 9 and Level: medium
# 	Question: 14 - 25 = ? and answer: -11
# Age: 9 and Level: hard
# 	Question: (15 + 3) - 2 and answer: 16
# Age: 10 and Level: easy
# ...
